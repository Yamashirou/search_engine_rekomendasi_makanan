# %%
import pandas as pd
import os

BASE_DIR = "../data_raw"
MAX_REVIEW = 100
MIN_WORDS = 5

# %%
areas = [
    d for d in os.listdir(BASE_DIR)
    if os.path.isdir(os.path.join(BASE_DIR, d))
]

print("Area ditemukan:", areas)
# Out:
# Area ditemukan: ['Jogja', 'Semarang', 'Surabaya']

# %%
import json

records = []

for area in areas:
    area_path = os.path.join(BASE_DIR, area)

    for file in os.listdir(area_path):
        if not file.endswith(".csv"):
            continue

        file_path = os.path.join(area_path, file)

        try:
            df = pd.read_csv(file_path)
        except Exception as e:
            print(f"Gagal baca {file}: {e}")
            continue

        
        required_cols = {'text', 'stars'}
        if not required_cols.issubset(df.columns):
            print(f"Kolom tidak sesuai di {file}")
            continue

        
        df = df[df['stars'] == 5]

        
        df['text'] = df['text'].astype(str)
        df = df[df['text'].str.split().str.len() >= MIN_WORDS]

        if df.empty:
            continue

        
        df_sample = df.head(MAX_REVIEW)

        
        combined_review = " ".join(df_sample['text'])

        
        sample_reviews = []
        for _, row in df_sample.iterrows():
            sample_reviews.append({
                "reviewer": row["name"] if "name" in df.columns else "Anonim",
                "text": row["text"],
                "stars": int(row["stars"])
            })

        
        records.append({
            "restaurant": file.replace(".csv", ""),
            "area": area,
            "review": combined_review,
            "sample_reviews": json.dumps(sample_reviews, ensure_ascii=False)
        })

# %%
df_merged = pd.DataFrame(records)

print("Total restoran:", len(df_merged))
df_merged.head()
# Out:
# Total restoran: 45
#                         restaurant   area  \
# 0   Ayam Goreng Jawa Mbah Cemplung  Jogja
# 1  Bale Raos - The Sultan's Dishes  Jogja
# 2                     Boyong Resto  Jogja
# 3               Gudeg Bu Djuminten  Jogja
# 4                      Gudeg Sagan  Jogja
#
#                                               review  \
# 0  Ayam Goreng Jawa Mbah Cemplung terkenal dengan...
# 1  Pertama kali cobain ke sini, tmptnya luas bang...
# 2  tempatnya bagus bgttt, makanan dan minumannya ...
# 3  Best gudeg for me (I'm not a local, and I alwa...
# 4  Untuk cita rasa gudeg, gudeg ini menurut saya ...
#
#                                       sample_reviews
# 0  [{"reviewer": "Keegantov Antonov", "text": "Ay...
# 1  [{"reviewer": "VD", "text": "Pertama kali coba...
# 2  [{"reviewer": "Jiran Utami Trisnawati", "text"...
# 3  [{"reviewer": "Anjani", "text": "Best gudeg fo...
# 4  [{"reviewer": "Y. J Sarah", "text": "Untuk cit...

# %%
os.makedirs("../output", exist_ok=True)
df_merged.to_csv("../output/kuliner_merged.csv", index=False)

print("Berhasil disimpan ke output/kuliner_merged.csv")
# Out:
# Berhasil disimpan ke output/kuliner_merged.csv
